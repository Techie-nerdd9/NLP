# %% [markdown]
# <a href="https://colab.research.google.com/github/Techie-nerdd9/NLP/blob/main/NLP_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gensim smart_open

# %%
import nltk
import urllib
import bs4 as bs
import re
import requests
from bs4 import BeautifulSoup
from gensim.models import Word2Vec

# %%
url = "https://en.wikipedia.org/wiki/Global_warming"

headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)
source = response.text

print("Page loaded successfully")
# Out:
# Page loaded successfully

# %%
soup = bs.BeautifulSoup(source, 'lxml')

text = ""

for paragraph in soup.find_all('p'):
    text += paragraph.text

print(text[:500])   # prints first part of text
# Out:
# Present-day climate change includes both global warming—the ongoing increase in global average temperature—and its wider effects on Earth's climate system. Climate change in a broader sense also includes previous long-term changes to Earth's climate. The modern-day rise in global temperatures is driven by human activities, especially fossil fuel (coal, oil and natural gas) burning since the Industrial Revolution.[3][4] Fossil fuel use, deforestation, and some agricultural and industrial practi

# %%
text = re.sub(r'\[[0-9]*\]', ' ', text)
text = re.sub(r'\s+', ' ', text)
text = text.lower()
text = re.sub(r'\d', ' ', text)
text = re.sub(r'\s+', ' ', text)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

print(sentences[:5])
# Out:
# [['present-day', 'climate', 'change', 'includes', 'both', 'global', 'warming—the', 'ongoing', 'increase', 'in', 'global', 'average', 'temperature—and', 'its', 'wider', 'effects', 'on', 'earth', "'s", 'climate', 'system', '.'], ['climate', 'change', 'in', 'a', 'broader', 'sense', 'also', 'includes', 'previous', 'long-term', 'changes', 'to', 'earth', "'s", 'climate', '.'], ['the', 'modern-day', 'rise', 'in', 'global', 'temperatures', 'is', 'driven', 'by', 'human', 'activities', ',', 'especially', 'fossil', 'fuel', '(', 'coal', ',', 'oil', 'and', 'natural', 'gas', ')', 'burning', 'since', 'the', 'industrial', 'revolution', '.'], ['fossil', 'fuel', 'use', ',', 'deforestation', ',', 'and', 'some', 'agricultural', 'and', 'industrial', 'practices', 'release', 'greenhouse', 'gases', '.'], ['these', 'gases', 'absorb', 'some', 'of', 'the', 'heat', 'that', 'the', 'earth', 'radiates', 'after', 'it', 'warms', 'from', 'sunlight', ',', 'warming', 'the', 'lower', 'atmosphere', '.']]

# %%
sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

print(sentences[:5])
# Out:
# [['present-day', 'climate', 'change', 'includes', 'both', 'global', 'warming—the', 'ongoing', 'increase', 'in', 'global', 'average', 'temperature—and', 'its', 'wider', 'effects', 'on', 'earth', "'s", 'climate', 'system', '.'], ['climate', 'change', 'in', 'a', 'broader', 'sense', 'also', 'includes', 'previous', 'long-term', 'changes', 'to', 'earth', "'s", 'climate', '.'], ['the', 'modern-day', 'rise', 'in', 'global', 'temperatures', 'is', 'driven', 'by', 'human', 'activities', ',', 'especially', 'fossil', 'fuel', '(', 'coal', ',', 'oil', 'and', 'natural', 'gas', ')', 'burning', 'since', 'the', 'industrial', 'revolution', '.'], ['fossil', 'fuel', 'use', ',', 'deforestation', ',', 'and', 'some', 'agricultural', 'and', 'industrial', 'practices', 'release', 'greenhouse', 'gases', '.'], ['these', 'gases', 'absorb', 'some', 'of', 'the', 'heat', 'that', 'the', 'earth', 'radiates', 'after', 'it', 'warms', 'from', 'sunlight', ',', 'warming', 'the', 'lower', 'atmosphere', '.']]

# %%
model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)

print("Word2Vec model trained successfully")
# Out:
# Word2Vec model trained successfully

# %%
print(model.wv.most_similar('climate'))
# Out:
# [('the', 0.9995929598808289), ('and', 0.9995694756507874), ('in', 0.9995644688606262), ('.', 0.9995492696762085), (',', 0.9995469450950623), ('of', 0.9995424151420593), ('to', 0.9995299577713013), ('that', 0.9994860887527466), ('have', 0.99945068359375), ('are', 0.9994259476661682)]

# %%
model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)

print("Word2Vec model trained successfully")
# Out:
# Word2Vec model trained successfully

# %%
print("Vector representation of 'climate':")
print(model.wv['climate'])
# Out:
# Vector representation of 'climate':
# [-0.14139207  0.3668738  -0.01622993  0.01362113  0.23644441 -0.46328732
#   0.15629464  0.7020058  -0.25805962 -0.22645578 -0.02362808 -0.37849647
#  -0.04674612  0.12010667  0.19364598 -0.16959375  0.18942766 -0.21608926
#  -0.19506715 -0.60632455  0.11283112  0.0120425   0.21558826 -0.20357169
#  -0.12241045 -0.01525402 -0.2999479  -0.1915062  -0.14499246  0.13179232
#   0.35032433 -0.0266322   0.1293771  -0.3216596  -0.05648087  0.38766062
#   0.05096493 -0.0825102  -0.20201963 -0.43008596  0.0557128  -0.20854494
#  -0.05349229  0.10257807  0.16948864 -0.0673965  -0.1842755  -0.05000988
#   0.11488214  0.20566624  0.3183775  -0.30328703  0.02119286 -0.12047616
#  -0.3149045   0.13147926  0.20727685  0.04133441 -0.35806376  0.20787948
#   0.18796247  0.05355898  0.11340187 -0.01889352 -0.33599633  0.22847295
#   0.23372374  0.43787    -0.46566966  0.4119438  -0.08230596  0.1399906
# ...

# %%
print("Words similar to 'climate':")
print(model.wv.most_similar('climate'))
# Out:
# Words similar to 'climate':
# [('the', 0.9995925426483154), ('and', 0.9995691776275635), ('in', 0.9995644092559814), ('.', 0.999549388885498), (',', 0.9995470643043518), ('of', 0.9995424151420593), ('to', 0.9995298385620117), ('that', 0.9994850158691406), ('have', 0.9994496703147888), ('are', 0.999426543712616)]
